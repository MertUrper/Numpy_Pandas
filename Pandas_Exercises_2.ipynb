# %%
import pandas as pd

# %% [markdown]
# ##### Youtube Dataset'ini Okuyun

# %%
youtube = pd.read_csv("USvideos.csv")

# %%
youtube.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %% [markdown]
# ##### İlk 5 Veriyi gösterin

# %%
youtube.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %% [markdown]
# ##### Datasetini aşağıdaki sütünları silerek güncelleyin.
#
# ###### thumbnail_link ,video_id,trending_date,publish_time,thumbnail_link,comments_disabled,ratings_disabled,video_error_or_removed

# %%
youtube.drop(["thumbnail_link","video_id","trending_date","publish_time","thumbnail_link",
              "comments_disabled","ratings_disabled","video_error_or_removed"],axis = 1,inplace = True)

# %%
youtube.columns
# Out:
# Index(['title', 'channel_title', 'category_id', 'tags', 'views', 'likes',
#        'dislikes', 'comment_count', 'description'],
#       dtype='object')

# %%
youtube.head()
# Out:
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id                                               tags    views  \
# 0           22                                    SHANtell martin   748374
# 1           24  last week tonight trump presidency|"last week ...  2418783
# 2           23  racist superman|"rudy"|"mancuso"|"king"|"bach"...  3191434
# 3           24  rhett and link|"gmm"|"good mythical morning"|"...   343168
# 4           24  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...  2095731
#
#     likes  dislikes  comment_count  \
# ...

# %% [markdown]
# ##### Kaç tane Sütün ve Kaç Tane Satır Olduğunu Bulun.

# %%
len(youtube.columns)      # sütun sayısı
# Out:
# 9

# %%
len(youtube.index)        # satır sayısı
# Out:
# 23362

# %%
youtube.shape             # satır, sütun sayısı
# Out:
# (23362, 9)

# %%
youtube.info()            # alternatif satır, sütun bilgisine erişim
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23362 entries, 0 to 23361
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          23362 non-null  object
#  1   channel_title  23362 non-null  object
#  2   category_id    23362 non-null  int64
#  3   tags           23362 non-null  object
#  4   views          23362 non-null  int64
#  5   likes          23362 non-null  int64
#  6   dislikes       23362 non-null  int64
#  7   comment_count  23362 non-null  int64
#  8   description    22929 non-null  object
# dtypes: int64(5), object(4)
# memory usage: 1.6+ MB

# %% [markdown]
# ##### Beğeni ve Beğenmeme sayılarının ortalamasını bulun

# %%
youtube["likes"].mean()          # beğeni ortalaması
# Out:
# 45085.35972947522

# %%
youtube["dislikes"].mean()       # beğenmeme ortalaması
# Out:
# 2809.7094426847016

# %% [markdown]
# ##### En yüksek görüntülenmeyi alan videonun başlık bilgisini bulun

# %%
youtube[youtube["views"] == youtube["views"].max()]    # bu şekilde direk satır gelir
# Out:
#                                                   title      channel_title  \
# 6181  YouTube Rewind: The Shape of 2017 | #YouTubeRe...  YouTube Spotlight
#
#       category_id                                               tags  \
# 6181           24  Rewind|"Rewind 2017"|"youtube rewind 2017"|"#Y...
#
#           views    likes  dislikes  comment_count  \
# 6181  149376127  3093544   1643059         810698
#
#                                             description
# 6181  YouTube Rewind 2017. Celebrating the videos, p...

# %%
youtube[youtube["views"] == youtube["views"].max()]["title"]     # index ile beraber gelir
# Out:
# 6181    YouTube Rewind: The Shape of 2017 | #YouTubeRe...
# Name: title, dtype: object

# %%
youtube[youtube["views"] == youtube["views"].max()]["title"].iloc[0]     # sadece başlık bilgisi
# Out:
# 'YouTube Rewind: The Shape of 2017 | #YouTubeRewind'

# %% [markdown]
# ##### En düşük görüntülenmeyi alan videonun başlık bilgisini bulun

# %%
youtube[youtube["views"].min() == youtube["views"]]["title"].iloc[0]
# Out:
# '1 dead, others injured after Ky. school shooting'

# %% [markdown]
# ##### Kategorilere Göre (category_id) Yorum Sayılarının Ortalamasını Bulun

# %%
youtube.groupby("category_id")[["comment_count"]].mean()
# Out:
#              comment_count
# category_id
# 1              6003.651813
# 2              1730.438235
# 10            10383.559418
# 15             2474.376054
# 17             3256.199515
# 19             1833.011450
# 20             7578.383607
# 22             4491.865854
# 23             5432.868554
# 24             7178.388176
# 25             1523.749869
# 26             4992.165997
# 27             2143.574850
# 28             3350.945159
# 29           100071.562500
# 43             1340.375000

# %%
youtube[["category_id","comment_count"]].groupby("category_id").mean()    # yukarıdaki ile aynı sonuc
# Out:
#              comment_count
# category_id
# 1              6003.651813
# 2              1730.438235
# 10            10383.559418
# 15             2474.376054
# 17             3256.199515
# 19             1833.011450
# 20             7578.383607
# 22             4491.865854
# 23             5432.868554
# 24             7178.388176
# 25             1523.749869
# 26             4992.165997
# 27             2143.574850
# 28             3350.945159
# 29           100071.562500
# 43             1340.375000

# %% [markdown]
# ##### Kategorilerde Kaç Adet Videonun Olduğunu Hesaplayın

# %%
youtube["category_id"].value_counts()
# Out:
# 24    5379
# 10    3366
# 26    2241
# 23    1978
# 25    1907
# 22    1886
# 28    1477
# 1     1324
# 17    1238
# 27    1002
# 15     593
# 2      340
# 20     305
# 19     262
# 29      48
# 43      16
# Name: category_id, dtype: int64

# %%
pd.DataFrame(youtube["category_id"].value_counts())      # dataframe formunda çıktı
# Out:
#     category_id
# 24         5379
# 10         3366
# 26         2241
# 23         1978
# 25         1907
# 22         1886
# 28         1477
# 1          1324
# 17         1238
# 27         1002
# 15          593
# 2           340
# 20          305
# 19          262
# 29           48
# 43           16

# %% [markdown]
# ##### Her Videonun Başlık Uzunluğunu içeren yeni bir sütün ekleyin.

# %%
youtube.title.str.len()            # alternatif yollar
# Out:
# 0        34
# 1        62
# 2        53
# 3        32
# 4        24
#          ..
# 23357    19
# 23358    29
# 23359    24
# 23360    45
# 23361    42
# Name: title, Length: 23362, dtype: int64

# %%
youtube["title"].transform(len)      # alternatif yollar
# Out:
# 0        34
# 1        62
# 2        53
# 3        32
# 4        24
#          ..
# 23357    19
# 23358    29
# 23359    24
# 23360    45
# 23361    42
# Name: title, Length: 23362, dtype: int64

# %%
youtube.title.apply(lambda x: len(x))          # alternatif yollar
# Out:
# 0        34
# 1        62
# 2        53
# 3        32
# 4        24
#          ..
# 23357    19
# 23358    29
# 23359    24
# 23360    45
# 23361    42
# Name: title, Length: 23362, dtype: int64

# %%
def countTitleCount(title):        
    return len(title)                 
youtube["title"].apply(countTitleCount)     # apply'a dışardan fonksiyon çağırma
# Out:
# 0        34
# 1        62
# 2        53
# 3        32
# 4        24
#          ..
# 23357    19
# 23358    29
# 23359    24
# 23360    45
# 23361    42
# Name: title, Length: 23362, dtype: int64

# %%
youtube["title_length"] = youtube["title"].apply(len)

# %%
youtube.head()
# Out:
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id                                               tags    views  \
# 0           22                                    SHANtell martin   748374
# 1           24  last week tonight trump presidency|"last week ...  2418783
# 2           23  racist superman|"rudy"|"mancuso"|"king"|"bach"...  3191434
# 3           24  rhett and link|"gmm"|"good mythical morning"|"...   343168
# 4           24  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...  2095731
#
#     likes  dislikes  comment_count  \
# ...

# %% [markdown]
# ##### Her bir videoda kullanılan etiket sayısını hesaplayarak, oluşan değerleri yeni bir sütun olarak ekleyin ve max etiket sayısını bulun
#
# Not: Her bir etiket "|" işaretiyle ayrılmaktadır.

# %%
def countTag(tags):
    tagList = tags.split("|")           
    return len(tagList)
youtube["tag_count"] = youtube["tags"].apply(countTag)

# %%
youtube.head()
# Out:
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id                                               tags    views  \
# 0           22                                    SHANtell martin   748374
# 1           24  last week tonight trump presidency|"last week ...  2418783
# 2           23  racist superman|"rudy"|"mancuso"|"king"|"bach"...  3191434
# 3           24  rhett and link|"gmm"|"good mythical morning"|"...   343168
# 4           24  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...  2095731
#
#     likes  dislikes  comment_count  \
# ...

# %%
# en fazla kaç etiket var
youtube.tag_count.max()
# Out:
# 69

# %%
# kaç tane max etikete sahip satır var
len(youtube[youtube.tag_count == youtube.tag_count.max()])
# Out:
# 4

# %%
# max etikete sahip olan kanal ismi 
youtube[youtube.tag_count == youtube.tag_count.max()]["channel_title"].iloc[0]
# Out:
# 'Marco Reps'

# %%
# df["tag_count"] = df["tags"].str.split("|").str.len()       bu yol daha kısa

# %% [markdown]
# #### category_id sütunu incele

# %%
youtube.category_id.mode().iloc[0]       # en çok tekrar eden kategori
# Out:
# 24

# %%
youtube.category_id.value_counts()
# Out:
# 24    5379
# 10    3366
# 26    2241
# 23    1978
# 25    1907
# 22    1886
# 28    1477
# 1     1324
# 17    1238
# 27    1002
# 15     593
# 2      340
# 20     305
# 19     262
# 29      48
# 43      16
# Name: category_id, dtype: int64

# %%
youtube.category_id.value_counts().plot(kind = "bar")       # category_id grafiksel gösterim
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### Videoları Beğeni Oranı en yüksek olandan en düşüğe doğru sıralayınız

# %%
# dikkat edilmesi gereken nokta oran üzerinden sıralama!!!!!
def likesAnddislikes(likes,dislikes):
    likesList = []
    dislikesList = []
    
    for key,value in likes.iteritems():        # likes.iteritems() = Iterate over (column name, Series) pairs.
        likesList.append(value)                # likes sayıları likesList'e atanmış oldu
    
    for key,value in dislikes.iteritems():
        dislikesList.append(value)
    
    likeanddislikeratio = []
    for like,dislike in zip(likesList,dislikesList): 
        if like + dislike == 0:                 # 0 olan satırlar vardı onlar direk oran olarak sıfır atandı
            likeanddislikeratio.append(0)
        else:
            likeanddislikeratio.append(like/(like + dislike))
    return likeanddislikeratio
        
youtube["likes_dislikes"] = likesAnddislikes(youtube["likes"],youtube["dislikes"])

# %%
youtube.sort_values(by = "likes_dislikes",ascending = False, inplace=True)

# %%
youtube.head()
# Out:
#                                                    title channel_title  \
# 8694                                  Christmas Day 2000      vnbreyes
# 16100                                  Magic Highway USA  Joshua Levin
# 921             #StarOnFox Exclusive Clip for TheYBF.com      YBF Chic
# 16369  First Responders Arrive To The Collapsed Floor...  9-1-1 on FOX
# 147    Improvising in the style of different classica...     Nahre Sol
#
#        category_id                                               tags  views  \
# 8694            17  Christmas|"Day"|"2000"|"Wallace"|"Lakers"|"Bla...   2987
# 16100           28                 Transportation|"Future"|"Highways"   5391
# 921             24                                             [none]   1975
# 16369           24  9-1-1|"first responders"|"police"|"firefighter...   1426
# 147             10  improvise classical music|"improvisation"|"cla...   5149
#
#        likes  dislikes  comment_count  \
# ...

# %%
# likes.iteritems() yerine .values.tolist() kullanımı daha pratik amaç sütundaki veriyi listeye çekmekti

'''
def likesAnddislikes(likes,dislikes):
    
    likesList1 = youtube['likes'].values.tolist() ---------> likes.iteritems() yerine soldaki yöntemde kullanılabilir
                                                             .values.tolist() ile daha pratik
    dislikesList1 = youtube['dislikes'].values.tolist()
    
    
    likeanddislikeratio = []
    for like,dislike in zip(likesList1,dislikesList1): 
        if like + dislike == 0:                 # 0 olan satırlar vardı onlar direk oran olarak sıfır atandı
            likeanddislikeratio.append(0)
        else:
            likeanddislikeratio.append(like/(like + dislike))
    return likeanddislikeratio
        
youtube["likes_dislikes"] = likesAnddislikes(youtube["likes"],youtube["dislikes"])

'''
# Out:
# '\ndef likesAnddislikes(likes,dislikes):\n    \n    likesList1 = youtube[\'likes\'].values.tolist() ---------> likes.iteritems() yerine soldaki yöntemde kullanılabilir\n                                                             .values.tolist() ile daha pratik\n    dislikesList1 = youtube[\'dislikes\'].values.tolist()\n    \n    \n    likeanddislikeratio = []\n    for like,dislike in zip(likesList1,dislikesList1): \n        if like + dislike == 0:                 # 0 olan satırlar vardı onlar direk oran olarak sıfır atandı\n            likeanddislikeratio.append(0)\n        else:\n            likeanddislikeratio.append(like/(like + dislike))\n    return likeanddislikeratio\n        \nyoutube["likes_dislikes"] = likesAnddislikes(youtube["likes"],youtube["dislikes"])\n\n'
